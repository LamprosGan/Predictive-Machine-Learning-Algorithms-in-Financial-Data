# %% [markdown]
# # Applying TransLOB model to reproduce the prediction results of horizon 10 for FI - 2010 Dataset.

# %%
# Importing the libraries.

import pandas as pd
import numpy as np
import tensorflow as tf
from keras import layers
from keras.layers import Conv1D, Layer, Concatenate, Dense, Activation, Add, Flatten, Dropout
from keras import backend as K
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %% [markdown]
# # Data Preparation

# %%
# Load the data and prepare the training, validation and test sets.
dec_data = np.loadtxt('Train_Dst_NoAuction_ZScore_CF_7.txt')
dec_train = dec_data[:, :int(np.floor(dec_data.shape[1] * 0.8))]
dec_val = dec_data[:, int(np.floor(dec_data.shape[1] * 0.8)):]

dec_test1 = np.loadtxt('Test_Dst_NoAuction_ZScore_CF_7.txt')
dec_test2 = np.loadtxt('Test_Dst_NoAuction_ZScore_CF_8.txt')
dec_test3 = np.loadtxt('Test_Dst_NoAuction_ZScore_CF_9.txt')
dec_test = np.hstack((dec_test1, dec_test2, dec_test3))

# %%
# Functions to prepare the data for the model.

def prepare_x(data):
    df1 = data[:40, :].T
    return np.array(df1)

def get_label(data):
    lob = data[-5:, :].T
    return lob

def data_classification(X, Y, T):
    [N, D] = X.shape
    df = np.array(X)

    dY = np.array(Y)

    dataY = dY[T - 1:N]

    dataX = np.zeros((N - T + 1, T, D))
    for i in range(T, N + 1):
        dataX[i - T] = df[i - T:i, :]

    return dataX, dataY

def prepare_x_y(data, k, T):
    x = prepare_x(data)
    y = get_label(data)
    x, y = data_classification(x, y, T=T)
    y = y[:,k] - 1
    y = to_categorical(y, 3)
    return x, y

k = 0  # Which horizon to use for prediction
T = 100  # The input dimension (time steps)
checkpoint_filepath = './model_translob_k0/weights' # Where to save the model weights.

# Prepare the data
X_train, y_train = prepare_x_y(dec_train, k, T)
X_val, y_val = prepare_x_y(dec_val, k, T)
X_test, y_test = prepare_x_y(dec_test, k, T)

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (203701, 100, 40)
# y_train shape: (203701, 3)
# X_val shape: (50851, 100, 40)
# y_val shape: (50851, 3)
# X_test shape: (139488, 100, 40)
# y_test shape: (139488, 3)

# %% [markdown]
# # Model Architecture

# %%
def lob_dilated(x):
  """
  TransLOB dilated 1-D convolution module
  """
  x = layers.Conv1D(14,kernel_size=2,strides=1,activation='relu',padding='causal')(x)   
  x = layers.Conv1D(14,kernel_size=2,dilation_rate=2,activation='relu',padding='causal')(x)
  x = layers.Conv1D(14,kernel_size=2,dilation_rate=4,activation='relu',padding='causal')(x)
  x = layers.Conv1D(14,kernel_size=2,dilation_rate=8,activation='relu',padding='causal')(x)
  y = layers.Conv1D(14,kernel_size=2,dilation_rate=16,activation='relu',padding='causal')(x)

  return y

class LayerNormalization(Layer):

    def __init__(self, axis=-1, **kwargs):
        self.axis = axis
        super().__init__(**kwargs)

    def get_config(self):
        config = super().get_config()
        config['axis'] = self.axis
        return config

    def build(self, input_shape):
        dim = input_shape[-1]
        self.gain = self.add_weight(
            name='gain',
            shape=(dim,),
            initializer='ones',
            trainable=True)
        self.bias = self.add_weight(
            name='bias',
            shape=(dim,),
            initializer='zeros',
            trainable=True)
        return super().build(input_shape)

    def call(self, inputs, **kwargs):
        mean = K.mean(inputs, axis=self.axis, keepdims=True)
        variance = K.mean(K.square(inputs - mean), axis=self.axis, keepdims=True)
        epsilon = K.constant(1e-5, dtype=K.floatx())
        normalized_inputs = (inputs - mean) / K.sqrt(variance + epsilon)
        return self.gain * normalized_inputs + self.bias


def positional_encoding(x):
  steps, d_model = x.get_shape().as_list()[-2:] 
  ps = np.zeros([steps,1],dtype=K.floatx()) 
  for tx in range(steps):
    ps[tx,:] = [(2/(steps-1))*tx - 1] 
  ps_expand = K.expand_dims(K.constant(ps),axis=0) 
  ps_tiled = K.tile(ps_expand,[K.shape(x)[0],1,1]) 
  x = K.concatenate([x,ps_tiled],axis=-1)
  return x

def multi_head_self_attention(inputs, num_heads, use_masking, d_model):
    # Validate dimensions
    if d_model % num_heads != 0:
        raise ValueError(f"The size of the last dimension of the input ({d_model}) must be evenly divisible by the number of attention heads ({num_heads}).")
    
    d_submodel = d_model // num_heads
    seq_len = tf.shape(inputs)[1]
    
    # Create Q, K, V transformations
    qkv_layer = Dense(d_model * 3, use_bias=False)
    qkv = qkv_layer(inputs)  # (batch_size, seq_len, d_model * 3)
    
    # Split and reshape Q, K, V
    q, k, v = tf.split(qkv, 3, axis=-1)
    q = tf.reshape(q, (-1, seq_len, num_heads, d_submodel))
    k = tf.reshape(k, (-1, seq_len, num_heads, d_submodel))
    v = tf.reshape(v, (-1, seq_len, num_heads, d_submodel))
    
    # Transpose for attention dot product: (batch_size, num_heads, seq_len, d_submodel)
    q = tf.transpose(q, [0, 2, 1, 3])
    k = tf.transpose(k, [0, 2, 1, 3])
    v = tf.transpose(v, [0, 2, 1, 3])
    
    # Scaled dot-product attention
    matmul_qk = tf.matmul(q, k, transpose_b=True)
    dk = tf.cast(d_submodel, dtype=tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

    # Masking
    if use_masking:
        mask = tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
        scaled_attention_logits += (mask * -1e9)

    # Softmax is applied to calculate attention coefficients
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)

    # Weighted sum of V with attention coefficients
    output = tf.matmul(attention_weights, v)
    
    # Reshape and transpose back to original input format
    output = tf.transpose(output, [0, 2, 1, 3])
    output = tf.reshape(output, (-1, seq_len, d_model))
    
    return output

def transformer_transition(inputs, activation='relu', size_multiplier=4):
    # Determine the dimensionality of the input feature space
    d_model = inputs.shape[-1]

    # Expand the dimensionality
    expanded_dim = size_multiplier * d_model
    dense_layer1 = Dense(expanded_dim, activation=activation, use_bias=True,
                         kernel_initializer='glorot_uniform', bias_initializer='zeros')
    step1 = dense_layer1(inputs)

    # Contract back to the original dimensionality
    dense_layer2 = Dense(d_model, use_bias=True, 
                         kernel_initializer='glorot_uniform', bias_initializer='zeros')
    output = dense_layer2(step1)

    return output

def transformer_block(inputs, num_heads, use_masking, size_multiplier=4):
    # Assuming multi_head_self_attention and transformer_transition are already defined
    # Multi-head Self-Attention
    attention_output = multi_head_self_attention(inputs, num_heads=num_heads, use_masking=use_masking, d_model=inputs.shape[-1])

    # Residual Connection and Custom Layer Normalization
    post_attention = Add()([inputs, attention_output])
    norm1_output = LayerNormalization()(post_attention)

    # Transition function
    transition_output = transformer_transition(norm1_output, activation='relu', size_multiplier=size_multiplier)

    # Second Residual Connection and Custom Layer Normalization
    post_transition = Add()([norm1_output, transition_output])
    final_output = LayerNormalization()(post_transition)

    return final_output

# %%
inputs = tf.keras.Input(shape=(100, 40))
x = lob_dilated(inputs)
x = LayerNormalization(axis=1)(x)
x = positional_encoding(x)
x = transformer_block(x, num_heads=3, use_masking=True)
x = transformer_block(x, num_heads=3, use_masking=True)
x = Flatten()(x)
x = Dense(64, activation='relu', kernel_regularizer='l2')(x)
x = Dropout(0.1)(x)
outputs = Dense(3, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),#, beta_1=0.9, beta_2=0.999,epsilon=1),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# 2024-08-08 16:23:35.542983: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 100, 40)]    0           []
#
#  conv1d (Conv1D)                (None, 100, 14)      1134        ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 100, 14)      406         ['conv1d[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 100, 14)      406         ['conv1d_1[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 100, 14)      406         ['conv1d_2[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 100, 14)      406         ['conv1d_3[0][0]']
#
#  layer_normalization (LayerNorm  (None, 100, 14)     28          ['conv1d_4[0][0]']
#  alization)
#
#  tf.compat.v1.shape (TFOpLambda  (3,)                0           ['layer_normalization[0][0]']
#  )
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.tile (TFOpLambda)           (None, 100, 1)       0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.concat (TFOpLambda)         (None, 100, 15)      0           ['layer_normalization[0][0]',
#                                                                   'tf.tile[0][0]']
#
#  dense (Dense)                  (None, 100, 45)      675         ['tf.concat[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (3,)                0           ['tf.concat[0][0]']
#  da)
#
#  tf.split (TFOpLambda)          [(None, 100, 15),    0           ['dense[0][0]']
#                                  (None, 100, 15),
#                                  (None, 100, 15)]
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.reshape (TFOpLambda)        (None, 100, 3, 5)    0           ['tf.split[0][0]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.reshape_1 (TFOpLambda)      (None, 100, 3, 5)    0           ['tf.split[0][1]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose (TFOpLa  (None, 3, 100, 5)   0           ['tf.reshape[0][0]']
#  mbda)
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 3, 100, 5)   0           ['tf.reshape_1[0][0]']
#  Lambda)
#
#  tf.ones (TFOpLambda)           (100, 100)           0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.linalg.matmul (TFOpLambda)  (None, 3, 100, 100)  0           ['tf.compat.v1.transpose[0][0]',
#                                                                   'tf.compat.v1.transpose_1[0][0]'
#                                                                  ]
#
#  tf.linalg.band_part (TFOpLambd  (100, 100)          0           ['tf.ones[0][0]']
#  a)
#
#  tf.math.truediv (TFOpLambda)   (None, 3, 100, 100)  0           ['tf.linalg.matmul[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (100, 100)           0           ['tf.linalg.band_part[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 3, 100, 100)  0          ['tf.math.truediv[0][0]',
#  da)                                                              'tf.math.multiply[0][0]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 100, 3, 5)    0           ['tf.split[0][2]',
#                                                                   'tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.nn.softmax (TFOpLambda)     (None, 3, 100, 100)  0           ['tf.__operators__.add[0][0]']
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 3, 100, 5)   0           ['tf.reshape_2[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_1 (TFOpLambda  (None, 3, 100, 5)   0           ['tf.nn.softmax[0][0]',
#  )                                                                'tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 100, 3, 5)   0           ['tf.linalg.matmul_1[0][0]']
#  Lambda)
#
#  tf.reshape_3 (TFOpLambda)      (None, 100, 15)      0           ['tf.compat.v1.transpose_3[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]']
#
#  add (Add)                      (None, 100, 15)      0           ['tf.concat[0][0]',
#                                                                   'tf.reshape_3[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 100, 15)     30          ['add[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 100, 60)      960         ['layer_normalization_1[0][0]']
#
#  dense_2 (Dense)                (None, 100, 15)      915         ['dense_1[0][0]']
#
#  add_1 (Add)                    (None, 100, 15)      0           ['layer_normalization_1[0][0]',
#                                                                   'dense_2[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 100, 15)     30          ['add_1[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 100, 45)      675         ['layer_normalization_2[0][0]']
#
#  tf.compat.v1.shape_2 (TFOpLamb  (3,)                0           ['layer_normalization_2[0][0]']
#  da)
#
#  tf.split_1 (TFOpLambda)        [(None, 100, 15),    0           ['dense_3[0][0]']
#                                  (None, 100, 15),
#                                  (None, 100, 15)]
#
#  tf.__operators__.getitem_2 (Sl  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  icingOpLambda)
#
#  tf.reshape_4 (TFOpLambda)      (None, 100, 3, 5)    0           ['tf.split_1[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.reshape_5 (TFOpLambda)      (None, 100, 3, 5)    0           ['tf.split_1[0][1]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 3, 100, 5)   0           ['tf.reshape_4[0][0]']
#  Lambda)
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 3, 100, 5)   0           ['tf.reshape_5[0][0]']
#  Lambda)
#
#  tf.ones_1 (TFOpLambda)         (100, 100)           0           ['tf.__operators__.getitem_2[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 3, 100, 100)  0          ['tf.compat.v1.transpose_4[0][0]'
#  )                                                               , 'tf.compat.v1.transpose_5[0][0]
#                                                                  ']
#
#  tf.linalg.band_part_1 (TFOpLam  (100, 100)          0           ['tf.ones_1[0][0]']
#  bda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 3, 100, 100)  0          ['tf.linalg.matmul_2[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (100, 100)          0           ['tf.linalg.band_part_1[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (None, 3, 100, 100)  0          ['tf.math.truediv_1[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  tf.reshape_6 (TFOpLambda)      (None, 100, 3, 5)    0           ['tf.split_1[0][2]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.nn.softmax_1 (TFOpLambda)   (None, 3, 100, 100)  0           ['tf.__operators__.add_1[0][0]']
#
#  tf.compat.v1.transpose_6 (TFOp  (None, 3, 100, 5)   0           ['tf.reshape_6[0][0]']
#  Lambda)
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 3, 100, 5)   0           ['tf.nn.softmax_1[0][0]',
#  )                                                                'tf.compat.v1.transpose_6[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_7 (TFOp  (None, 100, 3, 5)   0           ['tf.linalg.matmul_3[0][0]']
#  Lambda)
#
#  tf.reshape_7 (TFOpLambda)      (None, 100, 15)      0           ['tf.compat.v1.transpose_7[0][0]'
#                                                                  , 'tf.__operators__.getitem_2[0][
#                                                                  0]']
#
#  add_2 (Add)                    (None, 100, 15)      0           ['layer_normalization_2[0][0]',
#                                                                   'tf.reshape_7[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 100, 15)     30          ['add_2[0][0]']
#  rmalization)
#
#  dense_4 (Dense)                (None, 100, 60)      960         ['layer_normalization_3[0][0]']
#
#  dense_5 (Dense)                (None, 100, 15)      915         ['dense_4[0][0]']
#
#  add_3 (Add)                    (None, 100, 15)      0           ['layer_normalization_3[0][0]',
#                                                                   'dense_5[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 100, 15)     30          ['add_3[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 1500)         0           ['layer_normalization_4[0][0]']
#
#  dense_6 (Dense)                (None, 64)           96064       ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 3)            195         ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 104,265
# Trainable params: 104,265
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Training

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    verbose=1,
    callbacks=[early_stopping, model_checkpoint_callback])
# Out:
# Epoch 1/100
# 6366/6366 [==============================] - 199s 31ms/step - loss: 1.2423 - accuracy: 0.5954 - val_loss: 0.9275 - val_accuracy: 0.6338
# Epoch 2/100
# 6366/6366 [==============================] - 204s 32ms/step - loss: 0.9394 - accuracy: 0.5984 - val_loss: 0.9168 - val_accuracy: 0.6338
# Epoch 3/100
# 6366/6366 [==============================] - 206s 32ms/step - loss: 0.9129 - accuracy: 0.5984 - val_loss: 0.8904 - val_accuracy: 0.6338
# Epoch 4/100
# 6366/6366 [==============================] - 205s 32ms/step - loss: 0.8855 - accuracy: 0.5984 - val_loss: 0.8754 - val_accuracy: 0.6338
# Epoch 5/100
# 6366/6366 [==============================] - 207s 32ms/step - loss: 0.8722 - accuracy: 0.6142 - val_loss: 0.8673 - val_accuracy: 0.6354
# Epoch 6/100
# 6366/6366 [==============================] - 206s 32ms/step - loss: 0.8613 - accuracy: 0.6233 - val_loss: 0.8464 - val_accuracy: 0.6400
# Epoch 7/100
# 6366/6366 [==============================] - 205s 32ms/step - loss: 0.8525 - accuracy: 0.6271 - val_loss: 0.8337 - val_accuracy: 0.6441
# Epoch 8/100
# 6366/6366 [==============================] - 206s 32ms/step - loss: 0.8445 - accuracy: 0.6297 - val_loss: 0.8270 - val_accuracy: 0.6484
# Epoch 9/100
# 6366/6366 [==============================] - 207s 32ms/step - loss: 0.8371 - accuracy: 0.6325 - val_loss: 0.8147 - val_accuracy: 0.6482
# Epoch 10/100
# 6366/6366 [==============================] - 208s 33ms/step - loss: 0.8308 - accuracy: 0.6347 - val_loss: 0.8081 - val_accuracy: 0.6494
# Epoch 11/100
# 6366/6366 [==============================] - 206s 32ms/step - loss: 0.8265 - accuracy: 0.6357 - val_loss: 0.8077 - val_accuracy: 0.6575
# Epoch 12/100
# 6366/6366 [==============================] - 207s 32ms/step - loss: 0.8232 - accuracy: 0.6362 - val_loss: 0.8025 - val_accuracy: 0.6574
# Epoch 13/100
# 6366/6366 [==============================] - 207s 32ms/step - loss: 0.8214 - accuracy: 0.6363 - val_loss: 0.7992 - val_accuracy: 0.6559
# Epoch 14/100
# 6366/6366 [==============================] - 231s 36ms/step - loss: 0.8191 - accuracy: 0.6376 - val_loss: 0.7993 - val_accuracy: 0.6551
# Epoch 15/100
# 6366/6366 [==============================] - 240s 38ms/step - loss: 0.8175 - accuracy: 0.6374 - val_loss: 0.7945 - val_accuracy: 0.6546
# Epoch 16/100
# 6366/6366 [==============================] - 236s 37ms/step - loss: 0.8161 - accuracy: 0.6379 - val_loss: 0.7897 - val_accuracy: 0.6582
# Epoch 17/100
# 6366/6366 [==============================] - 233s 37ms/step - loss: 0.8150 - accuracy: 0.6381 - val_loss: 0.7963 - val_accuracy: 0.6565
# Epoch 18/100
# 6366/6366 [==============================] - 236s 37ms/step - loss: 0.8133 - accuracy: 0.6381 - val_loss: 0.7890 - val_accuracy: 0.6563
# Epoch 19/100
# 6366/6366 [==============================] - 234s 37ms/step - loss: 0.8119 - accuracy: 0.6386 - val_loss: 0.7860 - val_accuracy: 0.6565
# Epoch 20/100
# 6366/6366 [==============================] - 236s 37ms/step - loss: 0.8112 - accuracy: 0.6398 - val_loss: 0.7853 - val_accuracy: 0.6537
# Epoch 21/100
# 6366/6366 [==============================] - 243s 38ms/step - loss: 0.8100 - accuracy: 0.6393 - val_loss: 0.7877 - val_accuracy: 0.6550
# Epoch 22/100
# 6366/6366 [==============================] - 255s 40ms/step - loss: 0.8091 - accuracy: 0.6396 - val_loss: 0.7820 - val_accuracy: 0.6551
# Epoch 23/100
# 6366/6366 [==============================] - 268s 42ms/step - loss: 0.8081 - accuracy: 0.6395 - val_loss: 0.7858 - val_accuracy: 0.6551
# Epoch 24/100
# 6366/6366 [==============================] - 242s 38ms/step - loss: 0.8070 - accuracy: 0.6401 - val_loss: 0.7842 - val_accuracy: 0.6532
# Epoch 25/100
# 6366/6366 [==============================] - 244s 38ms/step - loss: 0.8067 - accuracy: 0.6404 - val_loss: 0.7829 - val_accuracy: 0.6542
# Epoch 26/100
# 6366/6366 [==============================] - 243s 38ms/step - loss: 0.8059 - accuracy: 0.6409 - val_loss: 0.7818 - val_accuracy: 0.6538
# Epoch 27/100
# 6366/6366 [==============================] - 238s 37ms/step - loss: 0.8037 - accuracy: 0.6416 - val_loss: 0.7891 - val_accuracy: 0.6545
# Epoch 28/100
# 6366/6366 [==============================] - 245s 38ms/step - loss: 0.8015 - accuracy: 0.6420 - val_loss: 0.7770 - val_accuracy: 0.6539
# Epoch 29/100
# 6366/6366 [==============================] - 242s 38ms/step - loss: 0.7995 - accuracy: 0.6432 - val_loss: 0.7760 - val_accuracy: 0.6560
# Epoch 30/100
# 6366/6366 [==============================] - 242s 38ms/step - loss: 0.7971 - accuracy: 0.6440 - val_loss: 0.7755 - val_accuracy: 0.6559
# Epoch 31/100
# 6366/6366 [==============================] - 241s 38ms/step - loss: 0.7947 - accuracy: 0.6454 - val_loss: 0.7772 - val_accuracy: 0.6554
# Epoch 32/100
# 6366/6366 [==============================] - 243s 38ms/step - loss: 0.7931 - accuracy: 0.6461 - val_loss: 0.7730 - val_accuracy: 0.6501
# Epoch 33/100
# 6366/6366 [==============================] - 240s 38ms/step - loss: 0.7914 - accuracy: 0.6468 - val_loss: 0.7737 - val_accuracy: 0.6510
# Epoch 34/100
# 6366/6366 [==============================] - 229s 36ms/step - loss: 0.7899 - accuracy: 0.6477 - val_loss: 0.7721 - val_accuracy: 0.6501
# Epoch 35/100
# 6366/6366 [==============================] - 229s 36ms/step - loss: 0.7891 - accuracy: 0.6488 - val_loss: 0.7760 - val_accuracy: 0.6493
# Epoch 36/100
# 6366/6366 [==============================] - 229s 36ms/step - loss: 0.7877 - accuracy: 0.6485 - val_loss: 0.7738 - val_accuracy: 0.6509
# Epoch 37/100
# 6366/6366 [==============================] - 230s 36ms/step - loss: 0.7873 - accuracy: 0.6483 - val_loss: 0.7723 - val_accuracy: 0.6507
# Epoch 38/100
# 6366/6366 [==============================] - 230s 36ms/step - loss: 0.7863 - accuracy: 0.6487 - val_loss: 0.7736 - val_accuracy: 0.6511
# Epoch 39/100
# 6366/6366 [==============================] - 231s 36ms/step - loss: 0.7860 - accuracy: 0.6489 - val_loss: 0.7689 - val_accuracy: 0.6505
# Epoch 40/100
# 6366/6366 [==============================] - 237s 37ms/step - loss: 0.7855 - accuracy: 0.6494 - val_loss: 0.7710 - val_accuracy: 0.6510
# Epoch 41/100
# 6366/6366 [==============================] - 233s 37ms/step - loss: 0.7848 - accuracy: 0.6501 - val_loss: 0.7686 - val_accuracy: 0.6505
# Epoch 42/100
# 6366/6366 [==============================] - 234s 37ms/step - loss: 0.7844 - accuracy: 0.6496 - val_loss: 0.7731 - val_accuracy: 0.6503
# Epoch 43/100
# 6366/6366 [==============================] - 234s 37ms/step - loss: 0.7841 - accuracy: 0.6504 - val_loss: 0.7737 - val_accuracy: 0.6521
# Epoch 44/100
# 6366/6366 [==============================] - 234s 37ms/step - loss: 0.7844 - accuracy: 0.6503 - val_loss: 0.7760 - val_accuracy: 0.6514
# Epoch 45/100
# 6366/6366 [==============================] - 235s 37ms/step - loss: 0.7835 - accuracy: 0.6500 - val_loss: 0.7716 - val_accuracy: 0.6510
# Epoch 46/100
# 6366/6366 [==============================] - 233s 37ms/step - loss: 0.7826 - accuracy: 0.6500 - val_loss: 0.7696 - val_accuracy: 0.6512
# Epoch 47/100
# 6366/6366 [==============================] - 234s 37ms/step - loss: 0.7827 - accuracy: 0.6504 - val_loss: 0.7677 - val_accuracy: 0.6504
# Epoch 48/100
# 6366/6366 [==============================] - 238s 37ms/step - loss: 0.7824 - accuracy: 0.6511 - val_loss: 0.7691 - val_accuracy: 0.6501
# Epoch 49/100
# 6366/6366 [==============================] - 235s 37ms/step - loss: 0.7814 - accuracy: 0.6510 - val_loss: 0.7705 - val_accuracy: 0.6499
# Epoch 50/100
# 6366/6366 [==============================] - 236s 37ms/step - loss: 0.7819 - accuracy: 0.6507 - val_loss: 0.7725 - val_accuracy: 0.6515
# Epoch 51/100
# 6366/6366 [==============================] - 237s 37ms/step - loss: 0.7813 - accuracy: 0.6513 - val_loss: 0.7685 - val_accuracy: 0.6505
# Epoch 52/100
# 6366/6366 [==============================] - 232s 36ms/step - loss: 0.7808 - accuracy: 0.6516 - val_loss: 0.7765 - val_accuracy: 0.6512
# Epoch 53/100
# 6366/6366 [==============================] - 232s 36ms/step - loss: 0.7809 - accuracy: 0.6514 - val_loss: 0.7696 - val_accuracy: 0.6497
# Epoch 54/100
# 6366/6366 [==============================] - 233s 37ms/step - loss: 0.7805 - accuracy: 0.6519 - val_loss: 0.7682 - val_accuracy: 0.6499

# %%
plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# # Model Testing

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions from one-hot encoding to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate the classification report
report = classification_report(y_true_classes, y_pred_classes, digits=4)
print(report)
# Out:
# 4359/4359 [==============================] - 59s 13ms/step
#               precision    recall  f1-score   support
#
#            0     0.4377    0.2792    0.3410     21127
#            1     0.7946    0.9593    0.8692     98602
#            2     0.3207    0.1131    0.1672     19759
#
#     accuracy                         0.7364    139488
#    macro avg     0.5177    0.4506    0.4591    139488
# weighted avg     0.6734    0.7364    0.6898    139488

# %%
# Compute the confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)


# Plotting using seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
